# %% [markdown]
# <a href="https://colab.research.google.com/github/charlie-aashutosh/-_-/blob/master/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# %%
# !pip install requests

# %%
#necessary libraries being imported
import sys
import time
import requests
import pandas as pd

# %%
#we use an except block just in case we dont get auth. from the website we want to scrap the information from
try:
  page=requests.get("https://www.cricbuzz.com/")

except Exception as e:
  error_type, error_obj, error_info = sys.exc_info()
  print('ERROR FOR LINK:', url)
  print(error_type, 'Line:', error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text, 'html.parser')
links=soup.find_all('div', attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#each line will be extracted from the 'links' object
for i in links:
  print(i.text)
  print("\n")
# Out:
# England rest Test regulars for Pakistan T20Is to be played at Manchester
#
#
# The deal - worth INR 222 crore - will run from August 18 to December 31, 2020
#
#
# The Delhi Capitals head coach believes the offspinner will be able to take the decision on his chin
#
#
# Graeme Smith concedes to have received death threats in the wake of expressing his support for Black Lives Matter (BLM), the newest twist in a tangled race debate
#
#
# Narine picked 2-19 before hitting a quickfire 50 in the chase
#
#
# Encapsulating the genius of MS Dhoni, in numbers
#
#
# Due to bad light and rain, only 134.3 overs were possible during the five days of the second Test against Pakistan at the Ageas Bowl
#
#
# The KXIP captain spoke of his excitement of leading KXIP in the upcoming IPL, but also revealed being worried about not being as good at his game when he returned
#
#
# South Africa were scheduled to play four ODIs and two T20Is in England
#
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a7c781563cd7> in <module>()
# ----> 1 i.text
#
# NameError: name 'i' is not defined
